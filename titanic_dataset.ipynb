# %%
import pandas as pd
import os
import numpy as np 
import sqlite3
os.getcwd()
# Out:
# '/Users/kendoka69/python_titanic_project'

# %%
os.path.isfile('titanic_data.csv')
# Out:
# True

# %%
# create the sqLite DB
db = sqlite3.connect("MyDemo.db")

# Read CSV into dataframe
df1 = pd.read_csv('titanic_data.csv')

# convert the pandas dataframe to a sqlite table
df1.to_sql("passenger_list", db, if_exists="replace")

def run_query(query):
    return pd.read_sql_query(query,db)

os.getcwd()


#add query here
query = '''
SELECT * FROM passenger_list'''
#pd.read_sql_query(query,db)
run_query(query)
# Out:
#       index  pclass  survived                                          name  \
# 0         0       1         1                 Allen, Miss. Elisabeth Walton
# 1         1       1         1                Allison, Master. Hudson Trevor
# 2         2       1         0                        Astor, Col. John Jacob
# 3         3       1         1  Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")
# 4         4       3         1                  McCormack, Mr. Thomas Joseph
# ...     ...     ...       ...                                           ...
# 1304   1304       3         0                            Markoff, Mr. Marin
# 1305   1305       3         0                            Markun, Mr. Johann
# 1306   1306       3         1                       Masselmani, Mrs. Fatima
# 1307   1307       3         0                          Matinoff, Mr. Nicola
# 1308   1308       3         1             McCarthy, Miss. Catherine "Katie"
#
# ...

# %%
query = """
SELECT MIN(age) AS min_age,
       MAX(age) AS max_age
  FROM passenger_list
"""
run_query(query)
# Out:
#    min_age  max_age
# 0   0.1667     80.0

# %%
query = """
SELECT COUNT(*), survived
FROM passenger_list
GROUP BY survived
"""
run_query(query)
# Out:
#    COUNT(*)  survived
# 0       809         0
# 1       500         1

# %%
len(df1)
# Out:
# 1309

# %%
df1.head()
# Out:
#    pclass  survived                                          name     sex  \
# 0       1      True                 Allen, Miss. Elisabeth Walton  female
# 1       1      True                Allison, Master. Hudson Trevor    male
# 2       1     False                        Astor, Col. John Jacob    male
# 3       1      True  Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")    male
# 4       3      True                  McCormack, Mr. Thomas Joseph    male
#
#        age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0     24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2    113781  151.5500  C22 C26        S   11    NaN
# 2  47.0000      1      0  PC 17757  227.5250  C62 C64        C  NaN  124.0
# 3  49.0000      1      0  PC 17485   56.9292      A20        C    1    NaN
# 4      NaN      0      0    367228    7.7500      NaN        Q  NaN    NaN
#
#                          home_dest
# ...

# %%
df1.count()
# Out:
# pclass       1309
# survived     1309
# name         1309
# sex          1309
# age          1046
# sibsp        1309
# parch        1309
# ticket       1309
# fare         1308
# cabin         295
# embarked     1307
# boat          486
# body          121
# home_dest     745
# dtype: int64

# %%
df1.dtypes
# Out:
# pclass         int64
# survived        bool
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home_dest     object
# dtype: object

# %%
df1.shape
# Out:
# (1309, 14)

# %%
df1.describe()

# %%
df1.Survived.value_counts().head()

# %%
df1.isnull().sum()
# Out:
# pclass       0
# survived     0
# name         0
# sex          0
# age          0
# sibsp        0
# parch        0
# ticket       0
# fare         0
# cabin        0
# embarked     0
# boat         0
# body         0
# home_dest    0
# dtype: int64

# %%
df1 = df1.replace("",'no information')
df1
# Out:
#       pclass  survived                                          name     sex  \
# 0          1      True                 Allen, Miss. Elisabeth Walton  female
# 1          1      True                Allison, Master. Hudson Trevor    male
# 2          1     False                        Astor, Col. John Jacob    male
# 3          1      True  Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")    male
# 4          3      True                  McCormack, Mr. Thomas Joseph    male
# ...      ...       ...                                           ...     ...
# 1304       3     False                            Markoff, Mr. Marin    male
# 1305       3     False                            Markun, Mr. Johann    male
# 1306       3      True                       Masselmani, Mrs. Fatima  female
# 1307       3     False                          Matinoff, Mr. Nicola    male
# 1308       3      True             McCarthy, Miss. Catherine "Katie"  female
#
# ...
